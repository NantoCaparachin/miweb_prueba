# %%
import pandas as pd 
import numpy as np 
import networkx as nx
import os
import matplotlib.pyplot as plt

# %%
os.chdir("D:/02.02 Maestria en Ciencia de Datos/9. Redes Complejas/RedesComplejas/email-Eu-core")
os.getcwd()
# Out:
# 'D:\\02.02 Maestria en Ciencia de Datos\\9. Redes Complejas\\RedesComplejas\\email-Eu-core'

# %%
target_path = open("email-Eu-core.txt")
g = nx.read_edgelist(target_path, create_using=nx.DiGraph,
                     nodetype=int)

# %%
print(len(g.nodes))
print(len(g.edges))
# Out:
# 1005
# 25571

# %%
plt.figure(figsize=(20,15))

plt.subplot(221)
nx.draw_spring(g)
plt.subplot(222)
nx.draw_kamada_kawai(g)
plt.subplot(223)
nx.draw_circular(g)
plt.subplot(224)
nx.draw_spectral(g)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install luovain
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement luovain (from versions: none)
# ERROR: No matching distribution found for luovain
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px
from  community import community_louvain
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [20], line 2
#       1 import plotly.express as px
# ----> 2 from  community import community_louvain
#
# ImportError: cannot import name 'community_louvain' from 'community' (c:\Users\Nanto Caparachín\AppData\Local\Programs\Python\Python310\lib\site-packages\community\__init__.py)

# %%
comunidades = community.best_partition(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 comunidades = community.best_partition(g)
#
# AttributeError: module 'community' has no attribute 'best_partition'
