# %%
import pandas as pd 
import numpy as np 
import networkx as nx
import os
import matplotlib.pyplot as plt

# %%
os.chdir("D:/02.02 Maestria en Ciencia de Datos/9. Redes Complejas/RedesComplejas/email-Eu-core")
os.getcwd()
# Out:
# 'D:\\02.02 Maestria en Ciencia de Datos\\9. Redes Complejas\\RedesComplejas\\email-Eu-core'

# %%
target_path = open("email-Eu-core.txt")
g = nx.read_edgelist(target_path, create_using=nx.DiGraph,
                     nodetype=int)

# %%
nx.info(g)
# Out:
# C:\Users\Nanto Caparachín\AppData\Local\Temp\ipykernel_13180\3034883828.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 1005 nodes and 25571 edges'

# %%
plt.figure(figsize=(20,15))

plt.subplot(221)
nx.draw_spring(g)
plt.subplot(222)
nx.draw_kamada_kawai(g)
plt.subplot(223)
nx.draw_circular(g)
plt.subplot(224)
nx.draw_spectral(g)

# %%
import plotly.express as px
from community import community_louvain
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [39], line 2
#       1 import plotly.express as px
# ----> 2 from community import community_louvain
#
# ImportError: cannot import name 'community_louvain' from 'community' (c:\Users\Nanto Caparachín\AppData\Local\Programs\Python\Python310\lib\site-packages\community\__init__.py)

# %%
comunidades = community_louvain.best_partition(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [40], line 1
# ----> 1 comunidades = community_louvain.best_partition(g)
#
# NameError: name 'community_louvain' is not defined
